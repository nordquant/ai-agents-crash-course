# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()
print("Environment variables loaded.", os.environ.get("OPENAI_API_KEY"))
if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# Environment variables loaded. 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
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Agent",
    instructions="""
    You are a helpful nutrition expert. Answer questions about nutrition in a concise manner.
    """,
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# Overall: yes, bananas are a healthy, nutrient-dense option when eaten as part of a balanced diet.
#
# Key nutrients per medium banana (about 118 g):
# - Potassium: supports blood pressure and heart health
# - Vitamin B6: helps with metabolism and brain function
# - Vitamin C: antioxidant and immune support
# - Dietary fiber: aids digestion and satiety
# - Resistant starch (more in unripe/green bananas): may benefit gut health
#
# Other notes:
# - Moderate calories (~105) and natural sugars; good for quick energy
# - Low fat; convenient, portable snack
# - Diabetic considerations: monitor portion due to carbs; pair with protein or fat to blunt blood sugar spikes
# - Choose ripe-to-yellow for sweeter taste; greener bananas have more resistant starch
#
# Bottom line: a healthy, convenient fruit with several benefits; enjoy in moderation as part of a varied diet.

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are a healthy, convenient fruit. Key points:
#
# - Nutrients: good source of potassium (supports blood pressure), vitamin B6, vitamin C, and dietary fiber.
# - Carbs: about 27 g per medium banana, mostly natural sugars; ripe bananas have more sugar but also more accessible energy.
# - Fiber: helps digestion and satiety; resistant starch in greener bananas may aid gut health.
# - Other: low in fat and protein; about 100 kcal per medium banana.
#
# Who should eat them: most people, including active individuals and those managing blood pressure.
#
# Cautions: if you have diabetes or need to limit sugar, enjoy in moderation or pair with protein/fat to balance blood sugar. Very large portions can add up calories and sugar.
#
# Bottom line: for most people, bananas are a nutritious, everyday fruit.

# %% [markdown]
# _Good Job!_
