# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name = "Nutrition Assistant",
    instructions=""" 
    You are a helpful assistant to give nutrition advice.
    You give concise answers
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are healthy in moderation. Key points:
#
#     - Nutrients: good source of potassium (supports heart and fluid balance), vitamin B6, vitamin C, and dietary fiber.
#     - Energy: about 105 calories for a medium banana; mostly carbs (natural sugars).
#     - Benefits: supports digestion, heart health, and provides quick energy; contains antioxidants.
#     - Considerations: higher sugar and carbs than some fruits; watch portion if you’re monitoring sugar or on a very low-carb diet; people with kidney issues may need potassium guidelines.
#     - Quick tips: pair with protein or fats (e.g., peanut butter) for staying power; ripe bananas have more sweetness and sugar.
#
#     If you have a specific goal (weight loss, diabetes, athletes, kids), I can tailor advice.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are generally very healthy as part of a balanced diet.
#
# Key benefits:
# - Rich in potassium (supports heart and muscle function)
# - Good source of vitamin B6, vitamin C, and dietary fiber
# - Provide quick, natural energy from carbs and low in fat
#
# Considerations:
# - Contain natural sugars; portion if watching blood sugar (1 medium banana ~105 calories)
# - Unripe bananas higher in starch; ripe are sweeter and easier to digest for some
# - Brushing or pair with protein/fat can help with blood sugar control and satiety
#
# Bottom line: bananas are a healthy, convenient fruit for most people when eaten in moderation.

# %% [markdown]
# _Good Job!_
